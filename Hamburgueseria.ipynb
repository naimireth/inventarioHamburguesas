# %% [markdown]
# <a href="https://colab.research.google.com/github/naimireth/inventarioHamburguesas/blob/main/Hamburgueseria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
inventario = 100
print(f"El inventario contiene {inventario} hamburguesas")
while inventario > 0:
  if inventario <= 10:
    print("Advertencia: El inventario esta casi vacio")
  num_hamburguesas = int(input("Cuantas hamburguesas desea comprar?"))
  if num_hamburguesas > inventario:
    print("No hay suficientes hamburguesas, solo quedan", inventario, "disponibles")
  else:
    inventario -= num_hamburguesas
    print(f"Haz comprado", num_hamburguesas, "hamburguesas, Nos quedan", inventario, "hamburguesas")
# Out:
# El inventario contiene 100 hamburguesas
# Cuantas hamburguesas desea comprar?105
# No hay suficientes hamburguesas, solo quedan 100 disponibles
# Cuantas hamburguesas desea comprar?100
# Haz comprado 100 hamburguesas, Nos quedan 0 hamburguesas

# %%
battery_level = 90
is_plugged_in = True

print(f"Inicia carga: {battery_level}%")

# El bucle se ejecuta mientras el nivel sea menor a 100
while battery_level < 100:
    battery_level += 2

    # Aseguramos que no sobrepase el 100%
    if battery_level > 100:
        battery_level = 100

    print(f"Cargando... {battery_level}%")

    # Mensajes según el estado de la carga
    if battery_level == 100:
        print("⚡ Bateria Completa! Por favor desconectar.")
    elif battery_level >= 98:
        print("Carga completa...")
# Out:
# Inicia carga: 90%
# Cargando... 92%
# Cargando... 94%
# Cargando... 96%
# Cargando... 98%
# Carga completa...
# Cargando... 100%
# ⚡ Bateria Completa! Por favor desconectar.
